# %%
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install seaborn

# import sys
# !conda install --yes --prefix {sys.prefix} numpy
# !conda install --yes --prefix {sys.prefix} matplotlib
# !conda install --yes --prefix {sys.prefix} pandas
# Out:
# Requirement already satisfied: numpy in /home/charlie/.local/lib/python3.8/site-packages (1.21.2)
# Requirement already satisfied: matplotlib in /home/charlie/.local/lib/python3.8/site-packages (3.4.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/charlie/.local/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/charlie/.local/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/charlie/.local/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3/dist-packages (from matplotlib) (2.7.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/charlie/.local/lib/python3.8/site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: numpy>=1.16 in /home/charlie/.local/lib/python3.8/site-packages (from matplotlib) (1.21.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from cycler>=0.10->matplotlib) (1.14.0)
# Requirement already satisfied: pandas in /home/charlie/.local/lib/python3.8/site-packages (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/lib/python3/dist-packages (from pandas) (2.7.3)
# Requirement already satisfied: numpy>=1.17.3 in /home/charlie/.local/lib/python3.8/site-packages (from pandas) (1.21.2)
# Requirement already satisfied: pytz>=2017.3 in /home/charlie/.local/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: seaborn in /home/charlie/.local/lib/python3.8/site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in /home/charlie/.local/lib/python3.8/site-packages (from seaborn) (1.3.2)
# Requirement already satisfied: numpy>=1.15 in /home/charlie/.local/lib/python3.8/site-packages (from seaborn) (1.21.2)
# Requirement already satisfied: scipy>=1.0 in /home/charlie/.local/lib/python3.8/site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: matplotlib>=2.2 in /home/charlie/.local/lib/python3.8/site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/lib/python3/dist-packages (from pandas>=0.23->seaborn) (2.7.3)
# Requirement already satisfied: pytz>=2017.3 in /home/charlie/.local/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2021.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/charlie/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/charlie/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/charlie/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (8.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/charlie/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.14.0)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
pd.set_option('max_columns', 10)
pd.set_option("max_rows", 10)

# %% [markdown]
# # THE DATASET
# This is the dataset downloaded from the WHO website. As you can see, it's not pretty...

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#     Unnamed: 0                                               2015  \
# 0          NaN   Raised blood pressure (SBP&gt;=140 OR DBP&gt;...
# 1          NaN                                         18+  years
# 2      Country                                         Both sexes
# 3  Afghanistan                                   30.6 [23.6-38.3]
# 4      Albania                                   29.0 [22.4-36.2]
#
#                                               2015.1  \
# 0   Raised blood pressure (SBP&gt;=140 OR DBP&gt;...
# 1                                         18+  years
# 2                                               Male
# 3                                   30.4 [20.4-41.6]
# 4                                   33.0 [23.0-44.3]
#
#                                               2015.2  \
# 0   Raised blood pressure (SBP&gt;=140 OR DBP&gt;...
# 1                                         18+  years
# 2                                             Female
# 3                                   30.7 [21.2-41.3]
# 4                                   25.0 [16.8-34.7]
#
#                                                 2014  ...  \
# 0   Raised blood pressure (SBP&gt;=140 OR DBP&gt;...  ...
# 1                                         18+  years  ...
# 2                                         Both sexes  ...
# 3                                   30.6 [23.9-37.8]  ...
# 4                                   29.2 [23.0-36.0]  ...
#
#                                               1976.1  \
# 0   Raised blood pressure (SBP&gt;=140 OR DBP&gt;...
# 1                                         18+  years
# 2                                               Male
# 3                                   25.2 [14.5-38.5]
# 4                                   34.5 [22.4-47.7]
#
#                                               1976.2  \
# 0   Raised blood pressure (SBP&gt;=140 OR DBP&gt;...
# 1                                         18+  years
# 2                                             Female
# 3                                   23.4 [13.3-35.6]
# 4                                   31.1 [20.1-44.2]
#
#                                                 1975  \
# 0   Raised blood pressure (SBP&gt;=140 OR DBP&gt;...
# 1                                         18+  years
# 2                                         Both sexes
# 3                                   24.2 [16.4-33.3]
# 4                                   33.1 [24.2-42.6]
#
#                                               1975.1  \
# 0   Raised blood pressure (SBP&gt;=140 OR DBP&gt;...
# 1                                         18+  years
# 2                                               Male
# 3                                   25.1 [13.9-38.9]
# 4                                   34.6 [21.9-48.6]
#
#                                               1975.2
# 0   Raised blood pressure (SBP&gt;=140 OR DBP&gt;...
# 1                                         18+  years
# 2                                             Female
# 3                                   23.2 [12.7-35.9]
# 4                                   31.3 [19.7-45.1]
#
# [5 rows x 124 columns]

# %% [markdown]
# # Renaming columns
# Let's start by renaming the columns (these are in bold at the top of the dataframe above). We will create a function which takes the old column name as input and returns a new improved column name.

# %%
def get_column_name(column):
    if column.name == 'Unnamed: 0':
        return 'Country'
    else:
        return column.name[:4] + f' ({column.iloc[2][1:]})'

# %% [markdown]
# Now let's assign the columns property of the dataframe (df.columns) to a list where each element of the list is generated by insterting

# %%
df.columns = [get_column_name(df[column]) for column in df.columns]

# %% [markdown]
# # Removing the 1st 3 rows

# %%
df = df.iloc[3:, 0:]
df
# Out:
#                                 Country 2015 (Both sexes)       2015 (Male)  \
# 3                           Afghanistan  30.6 [23.6-38.3]  30.4 [20.4-41.6]
# 4                               Albania  29.0 [22.4-36.2]  33.0 [23.0-44.3]
# 5                               Algeria  25.1 [19.4-31.5]  25.4 [17.1-35.2]
# 6                               Andorra  18.7 [13.3-24.8]  23.2 [14.3-33.5]
# 7                                Angola  29.7 [22.1-38.3]  29.6 [18.1-42.7]
# ..                                  ...               ...               ...
# 193  Venezuela (Bolivarian Republic of)  18.6 [13.7-24.1]  21.5 [13.8-30.5]
# 194                            Viet Nam  23.4 [18.0-29.4]  25.0 [16.8-34.1]
# 195                               Yemen  30.7 [23.3-38.7]  29.9 [19.5-41.6]
# 196                              Zambia  27.1 [20.8-34.1]  27.6 [18.1-38.5]
# 197                            Zimbabwe  28.2 [21.6-35.7]  26.9 [17.5-37.4]
#
#         2015 (Female) 2014 (Both sexes)  ...       1976 (Male)  \
# 3    30.7 [21.2-41.3]  30.6 [23.9-37.8]  ...  25.2 [14.5-38.5]
# 4    25.0 [16.8-34.7]  29.2 [23.0-36.0]  ...  34.5 [22.4-47.7]
# 5    24.6 [16.6-33.6]  25.4 [20.0-31.5]  ...  30.6 [18.2-44.1]
# 6     14.2 [8.3-21.5]  19.2 [14.0-24.9]  ...  41.3 [28.8-53.6]
# 7    29.6 [19.2-41.3]  29.8 [22.6-38.0]  ...  28.5 [15.8-44.1]
# ..                ...               ...  ...               ...
# 193   15.7 [9.9-22.8]  19.0 [14.3-24.2]  ...  35.1 [22.6-48.2]
# 194  21.6 [14.7-29.5]  23.4 [18.2-28.9]  ...  21.7 [12.1-34.4]
# 195  31.2 [21.2-42.4]  30.7 [23.7-38.2]  ...  25.4 [13.6-39.7]
# 196  26.5 [18.2-36.5]  27.2 [21.2-33.7]  ...  30.5 [19.4-43.0]
# 197  29.2 [20.2-39.1]  28.3 [22.0-35.3]  ...  28.5 [16.7-42.3]
#
#         1976 (Female) 1975 (Both sexes)       1975 (Male)     1975 (Female)
# 3    23.4 [13.3-35.6]  24.2 [16.4-33.3]  25.1 [13.9-38.9]  23.2 [12.7-35.9]
# 4    31.1 [20.1-44.2]  33.1 [24.2-42.6]  34.6 [21.9-48.6]  31.3 [19.7-45.1]
# 5    32.1 [20.4-45.5]  31.5 [22.5-41.2]  30.7 [17.6-45.0]  32.1 [19.6-46.1]
# 6    34.4 [23.3-46.5]  37.9 [29.1-47.1]  41.3 [28.1-54.4]  34.6 [22.9-47.3]
# 7    25.9 [14.8-39.4]  27.0 [18.2-37.3]  28.3 [15.2-44.6]  25.6 [14.2-39.9]
# ..                ...               ...               ...               ...
# 193  33.5 [22.0-46.6]  34.5 [25.5-44.2]  35.1 [22.0-49.0]  33.6 [21.5-47.4]
# 194  18.8 [10.3-29.8]  20.3 [13.4-28.7]  21.7 [11.5-35.3]   18.7 [9.9-30.4]
# 195  26.3 [15.2-39.9]  25.8 [16.9-35.6]  25.4 [13.1-40.6]  26.1 [14.4-40.6]
# 196  27.2 [17.1-38.7]  28.7 [20.6-37.4]  30.3 [18.7-43.5]  27.0 [16.4-39.3]
# 197  27.4 [16.7-40.1]  27.8 [19.3-37.5]  28.3 [16.1-43.0]  27.2 [16.0-40.7]
#
# [195 rows x 124 columns]

# %% [markdown]
# # Making the country column the index of df

# %%
df = df.set_index('Country')

df
# Out:
#                                    2015 (Both sexes)       2015 (Male)  \
# Country
# Afghanistan                         30.6 [23.6-38.3]  30.4 [20.4-41.6]
# Albania                             29.0 [22.4-36.2]  33.0 [23.0-44.3]
# Algeria                             25.1 [19.4-31.5]  25.4 [17.1-35.2]
# Andorra                             18.7 [13.3-24.8]  23.2 [14.3-33.5]
# Angola                              29.7 [22.1-38.3]  29.6 [18.1-42.7]
# ...                                              ...               ...
# Venezuela (Bolivarian Republic of)  18.6 [13.7-24.1]  21.5 [13.8-30.5]
# Viet Nam                            23.4 [18.0-29.4]  25.0 [16.8-34.1]
# Yemen                               30.7 [23.3-38.7]  29.9 [19.5-41.6]
# Zambia                              27.1 [20.8-34.1]  27.6 [18.1-38.5]
# Zimbabwe                            28.2 [21.6-35.7]  26.9 [17.5-37.4]
#
#                                        2015 (Female) 2014 (Both sexes)  \
# Country
# Afghanistan                         30.7 [21.2-41.3]  30.6 [23.9-37.8]
# Albania                             25.0 [16.8-34.7]  29.2 [23.0-36.0]
# Algeria                             24.6 [16.6-33.6]  25.4 [20.0-31.5]
# Andorra                              14.2 [8.3-21.5]  19.2 [14.0-24.9]
# Angola                              29.6 [19.2-41.3]  29.8 [22.6-38.0]
# ...                                              ...               ...
# Venezuela (Bolivarian Republic of)   15.7 [9.9-22.8]  19.0 [14.3-24.2]
# Viet Nam                            21.6 [14.7-29.5]  23.4 [18.2-28.9]
# Yemen                               31.2 [21.2-42.4]  30.7 [23.7-38.2]
# Zambia                              26.5 [18.2-36.5]  27.2 [21.2-33.7]
# Zimbabwe                            29.2 [20.2-39.1]  28.3 [22.0-35.3]
#
#                                          2014 (Male)  ...       1976 (Male)  \
# Country                                               ...
# Afghanistan                         30.4 [21.0-41.0]  ...  25.2 [14.5-38.5]
# Albania                             33.2 [23.9-43.7]  ...  34.5 [22.4-47.7]
# Algeria                             25.7 [17.9-34.9]  ...  30.6 [18.2-44.1]
# Andorra                             23.7 [15.1-33.4]  ...  41.3 [28.8-53.6]
# Angola                              29.8 [18.8-42.2]  ...  28.5 [15.8-44.1]
# ...                                              ...  ...               ...
# Venezuela (Bolivarian Republic of)  21.9 [14.6-30.3]  ...  35.1 [22.6-48.2]
# Viet Nam                            24.9 [17.2-33.4]  ...  21.7 [12.1-34.4]
# Yemen                               29.8 [20.1-41.0]  ...  25.4 [13.6-39.7]
# Zambia                              27.7 [18.8-37.8]  ...  30.5 [19.4-43.0]
# Zimbabwe                            27.0 [18.1-36.6]  ...  28.5 [16.7-42.3]
#
#                                        1976 (Female) 1975 (Both sexes)  \
# Country
# Afghanistan                         23.4 [13.3-35.6]  24.2 [16.4-33.3]
# Albania                             31.1 [20.1-44.2]  33.1 [24.2-42.6]
# Algeria                             32.1 [20.4-45.5]  31.5 [22.5-41.2]
# Andorra                             34.4 [23.3-46.5]  37.9 [29.1-47.1]
# Angola                              25.9 [14.8-39.4]  27.0 [18.2-37.3]
# ...                                              ...               ...
# Venezuela (Bolivarian Republic of)  33.5 [22.0-46.6]  34.5 [25.5-44.2]
# Viet Nam                            18.8 [10.3-29.8]  20.3 [13.4-28.7]
# Yemen                               26.3 [15.2-39.9]  25.8 [16.9-35.6]
# Zambia                              27.2 [17.1-38.7]  28.7 [20.6-37.4]
# Zimbabwe                            27.4 [16.7-40.1]  27.8 [19.3-37.5]
#
#                                          1975 (Male)     1975 (Female)
# Country
# Afghanistan                         25.1 [13.9-38.9]  23.2 [12.7-35.9]
# Albania                             34.6 [21.9-48.6]  31.3 [19.7-45.1]
# Algeria                             30.7 [17.6-45.0]  32.1 [19.6-46.1]
# Andorra                             41.3 [28.1-54.4]  34.6 [22.9-47.3]
# Angola                              28.3 [15.2-44.6]  25.6 [14.2-39.9]
# ...                                              ...               ...
# Venezuela (Bolivarian Republic of)  35.1 [22.0-49.0]  33.6 [21.5-47.4]
# Viet Nam                            21.7 [11.5-35.3]   18.7 [9.9-30.4]
# Yemen                               25.4 [13.1-40.6]  26.1 [14.4-40.6]
# Zambia                              30.3 [18.7-43.5]  27.0 [16.4-39.3]
# Zimbabwe                            28.3 [16.1-43.0]  27.2 [16.0-40.7]
#
# [195 rows x 123 columns]

# %% [markdown]
# # Removing the range part of the blood pressure data

# %%
def remove_range(element):
    return element.split(' ')[0]

# %%
for column in df.columns:
    if column != 'Country':
        df[column] = df[column].apply(remove_range)
df
# Out:
#                                    2015 (Both sexes) 2015 (Male)  \
# Country
# Afghanistan                                     30.6        30.4
# Albania                                         29.0        33.0
# Algeria                                         25.1        25.4
# Andorra                                         18.7        23.2
# Angola                                          29.7        29.6
# ...                                              ...         ...
# Venezuela (Bolivarian Republic of)              18.6        21.5
# Viet Nam                                        23.4        25.0
# Yemen                                           30.7        29.9
# Zambia                                          27.1        27.6
# Zimbabwe                                        28.2        26.9
#
#                                    2015 (Female) 2014 (Both sexes)  \
# Country
# Afghanistan                                 30.7              30.6
# Albania                                     25.0              29.2
# Algeria                                     24.6              25.4
# Andorra                                     14.2              19.2
# Angola                                      29.6              29.8
# ...                                          ...               ...
# Venezuela (Bolivarian Republic of)          15.7              19.0
# Viet Nam                                    21.6              23.4
# Yemen                                       31.2              30.7
# Zambia                                      26.5              27.2
# Zimbabwe                                    29.2              28.3
#
#                                    2014 (Male)  ... 1976 (Male) 1976 (Female)  \
# Country                                         ...
# Afghanistan                               30.4  ...        25.2          23.4
# Albania                                   33.2  ...        34.5          31.1
# Algeria                                   25.7  ...        30.6          32.1
# Andorra                                   23.7  ...        41.3          34.4
# Angola                                    29.8  ...        28.5          25.9
# ...                                        ...  ...         ...           ...
# Venezuela (Bolivarian Republic of)        21.9  ...        35.1          33.5
# Viet Nam                                  24.9  ...        21.7          18.8
# Yemen                                     29.8  ...        25.4          26.3
# Zambia                                    27.7  ...        30.5          27.2
# Zimbabwe                                  27.0  ...        28.5          27.4
#
#                                    1975 (Both sexes) 1975 (Male) 1975 (Female)
# Country
# Afghanistan                                     24.2        25.1          23.2
# Albania                                         33.1        34.6          31.3
# Algeria                                         31.5        30.7          32.1
# Andorra                                         37.9        41.3          34.6
# Angola                                          27.0        28.3          25.6
# ...                                              ...         ...           ...
# Venezuela (Bolivarian Republic of)              34.5        35.1          33.6
# Viet Nam                                        20.3        21.7          18.7
# Yemen                                           25.8        25.4          26.1
# Zambia                                          28.7        30.3          27.0
# Zimbabwe                                        27.8        28.3          27.2
#
# [195 rows x 123 columns]

# %% [markdown]
# ## Creating a new dataset (df_both) which only contains the (BothSexes) Columns from df

# %%
lst = []

for column in df.columns[1:]:
    print(column.split(' ')[1])
    if column.split(' ')[1] != '(Both ':
        lst.append(column)

df_both = df.drop(labels=lst, axis=1)

df_both.columns = [column.split(' ')[0] for column in df_both.columns]
# Out:
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)
# (Both
# (Male)
# (Female)

# %% [markdown]
# # Realising that for some countries, there is "No" data:

# %%
df_both.loc['Sudan']
# Out:
# 2015    No
# Name: Sudan, dtype: object

# %% [markdown]
# # Finding these countries

# %%
countries = df_both.index

countries_to_remove = []

for country in countries:
    if df_both.loc[country]['2015'] == 'No':
        countries_to_remove.append(country)
        
countries_to_remove
# Out:
# ['Monaco', 'San Marino', 'South Sudan', 'Sudan']

# %% [markdown]
# # Removing these countries

# %%
df_both = df_both.drop(countries_to_remove)

# %% [markdown]
# # Converting the string values to floats

# %%
for column in df_both.columns:
    df_both[column] = pd.to_numeric(df_both[column], downcast='float')

# %% [markdown]
# ### Transposing the data so that the years become the rows to fit with seaborn lineplot() function

# %%
df_both = df_both.transpose()

df_both
# Out:
# Country  Afghanistan  Albania  Algeria    Andorra     Angola  ...  \
# 2015            30.6     29.0     25.1  18.700001  29.700001  ...
#
# Country  Venezuela (Bolivarian Republic of)  Viet Nam      Yemen  Zambia  \
# 2015                                   18.6      23.4  30.700001    27.1
#
# Country   Zimbabwe
# 2015     28.200001
#
# [1 rows x 191 columns]

# %% [markdown]
# ## Creating a line plotting function which takes countries to plot as arguments

# %%
def line_plot(countries):
    plt.figure(figsize=(10,6))

    lst = np.arange(0,41,5)
    plt.xticks(lst)
    
    plt.title("How has blood pressure has varied in different countries between 1975 and 2015")
    plt.ylabel('Blood pressure')
    plt.xlabel('Year')

    sns.lineplot(data=df_both[countries].iloc[::-1])
    
line_plot(['Uruguay', 'United States of America', 'Zambia', 'Zimbabwe'])
